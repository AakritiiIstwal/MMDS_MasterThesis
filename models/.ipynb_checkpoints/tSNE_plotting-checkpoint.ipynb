# %%
import numpy as np
import pandas as pd
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# %%
encoder_df = pd.read_pickle("encoder_data/conv_autoencoder_150_50.pkl")

# %%
encoder_df
# Out:
#             Label                                     Encoder Output
# 0             bus  [0.0, 12.391744, 30.256796, 18.027126, 14.5293...
# 1             bus  [0.0, 12.391744, 30.256796, 18.027126, 14.5293...
# 2             bus  [0.0, 12.391744, 30.256796, 18.027126, 14.5293...
# 3             bus  [0.0, 12.391744, 30.256796, 18.027126, 14.5293...
# 4             bus  [0.0, 12.391744, 30.256796, 18.027126, 14.5293...
# ...           ...                                                ...
# 2995  tubestation  [6.295613, 9.753875, 31.900227, 27.87225, 19.5...
# 2996  tubestation  [6.295613, 9.753875, 31.900227, 27.87225, 19.5...
# 2997  tubestation  [6.295613, 9.753875, 31.900227, 27.87225, 19.5...
# 2998  tubestation  [6.295613, 9.753875, 31.900227, 27.87225, 19.5...
# 2999  tubestation  [6.295613, 9.753875, 31.900227, 27.87225, 19.5...
#
# [3000 rows x 2 columns]

# %%
labels = encoder_df["Label"]
labels
# Out:
# 0               bus
# 1               bus
# 2               bus
# 3               bus
# 4               bus
#            ...
# 2995    tubestation
# 2996    tubestation
# 2997    tubestation
# 2998    tubestation
# 2999    tubestation
# Name: Label, Length: 3000, dtype: object

# %%
from matplotlib.cm import get_cmap

# Create a color mapping from unique labels to colors using a colormap
label_unique = np.unique(labels)
color_map = get_cmap('tab10', len(label_unique))  # 'viridis' is just one option for a colormap
label_to_color = {key: color_map(i) for i, key in enumerate(label_unique)}
# Out:
# /tmp/ipykernel_1638810/4017948233.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   color_map = get_cmap('viridis', len(label_unique))  # 'viridis' is just one option for a colormap

# %%
# Map labels to colors
colors = labels.map(label_to_color)

# %%
encoder_df['Encoder Output'].values
# Out:
# array([array([ 0.      , 12.391744, 30.256796, ..., 16.32649 , 20.717762,
#               42.37139 ], dtype=float32)                                 ,
#        array([ 0.      , 12.391744, 30.256796, ..., 63.994766, 63.065876,
#               61.822906], dtype=float32)                                 ,
#        array([ 0.      , 12.391744, 30.256796, ..., 63.994766, 63.065876,
#               62.51169 ], dtype=float32)                                 ,
#        ...,
#        array([ 6.295613,  9.753875, 31.900227, ..., 70.44307 , 65.529724,
#               66.42587 ], dtype=float32)                                 ,
#        array([ 6.295613,  9.753875, 31.900227, ..., 73.13775 , 60.075115,
#               64.31959 ], dtype=float32)                                 ,
#        array([ 6.295613,  9.753875, 31.900227, ..., 70.027664, 64.31181 ,
#               66.594826], dtype=float32)                                 ],
#       dtype=object)

# %%
# Convert DataFrame column with lists into a numpy matrix for t-SNE
data_matrix = np.stack(encoder_df['Encoder Output'].values)

# %%
data_matrix.shape
# Out:
# (3000, 60160)

# %%
tsne = TSNE(n_components=2, perplexity=1000, n_iter=1000, random_state=42)
tsne_results = tsne.fit_transform(data_matrix)

# %%
tsne_results.shape
# Out:
# (3000, 2)

# %%
tsne_results
# Out:
# array([[ 2.7807746 , -0.26182637],
#        [ 2.9483314 , -0.49434787],
#        [ 2.2338693 , -0.15366304],
#        ...,
#        [-0.4961883 ,  0.67769355],
#        [-0.86967635,  0.5134632 ],
#        [-1.2212209 ,  0.47374088]], dtype=float32)

# %%
colors
# Out:
# 0       (0.267004, 0.004874, 0.329415, 1.0)
# 1       (0.267004, 0.004874, 0.329415, 1.0)
# 2       (0.267004, 0.004874, 0.329415, 1.0)
# 3       (0.267004, 0.004874, 0.329415, 1.0)
# 4       (0.267004, 0.004874, 0.329415, 1.0)
#                        ...
# 2995    (0.993248, 0.906157, 0.143936, 1.0)
# 2996    (0.993248, 0.906157, 0.143936, 1.0)
# 2997    (0.993248, 0.906157, 0.143936, 1.0)
# 2998    (0.993248, 0.906157, 0.143936, 1.0)
# 2999    (0.993248, 0.906157, 0.143936, 1.0)
# Name: Label, Length: 3000, dtype: object

# %%
# Plotting
plt.figure(figsize=(10, 10))
scatter = plt.scatter(tsne_results[:, 0], tsne_results[:, 1], c=colors, alpha=0.5)
plt.title('t-SNE Visualization of Encoder Outputs')
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.show()

# %%
label_unique
# Out:
# array(['bus', 'busystreet', 'office', 'openairmarket', 'park',
#        'quietstreet', 'restaurant', 'supermarket', 'tube', 'tubestation'],
#       dtype=object)

# %%
from sklearn.cluster import KMeans

# Assuming tsne_results contains your t-SNE output
kmeans = KMeans(n_clusters=10, random_state=42)
clusters = kmeans.fit_predict(tsne_results)

# Plotting with cluster coloring
plt.figure(figsize=(10, 10))
scatter = plt.scatter(tsne_results[:, 0], tsne_results[:, 1], c=clusters, cmap='viridis', alpha=0.5)
plt.title('t-SNE Visualization with K-means Clustering')
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.colorbar(scatter, label='Cluster ID')
plt.show()
